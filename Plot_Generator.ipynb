# %%
import matplotlib.pyplot as plt
import numpy as np


generations = [20,31.5,32,33,34,36,38,40]
order_index_values = [
    0.045818948393162945,
    0.045819427219605004,
    0.045818878606052854,
    0.04581830884152778,
    0.045813616269371804,
    0.04581318890042921,
    0.04581033629231059,
    0.045812812319631614
]

# trendline
z = np.polyfit(generations, order_index_values, 1)
p = np.poly1d(z)
# 4. Plot the trend line
# "r--" specifies a red dashed line
plt.plot(generations, p(generations), "r--", label='Trend Line')

plt.plot(generations,order_index_values)
plt.plot(generations,order_index_values,'ko')
plt.xlabel('Thousands of Generations',size=14)
plt.ylabel('Order Index',size=14);

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
strains = ['REL606', 'ara-6\n(avg.)', 'ara+4\n(avg.)', 'ara-6/ara+4\n(avg.)']
order_index_values = [0.04581664735304153, 0.04584470124646217, 0.04555373786915687, 0.04569921955780952]

# Create the bar chart
plt.bar(strains, order_index_values, color='skyblue')
plt.ylim(.045, .046)

# Add labels and title
plt.title('Order Index Values at 50k Generations')
plt.xlabel('Strains')
plt.ylabel('Order Index Value')

# Display the plot
plt.show()

# %%
# just using python to calculate to preserve significant digits
print((0.04581664735304153 - 0.04569921955780952))
# Out:
# 0.00011742779523200852
